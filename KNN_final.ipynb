# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %matplotlib inline

# %%
cirr = pd.read_csv('../datasets/cirr_knn.csv')

# %%
cirr['bilirubin'] = cirr['bilirubin'].astype(int)
cirr['prothrombin'] = cirr['prothrombin'].astype(int)
cirr['stage'] = cirr['stage'].astype(int)

# %%
cirr.head(10)
# Out:
#    id  n_days status             drug    age sex ascites hepatomegaly spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
# 5   7    1832      C          Placebo  20284   F       N            Y       N
# 6   8    2466      D          Placebo  19379   F       N            N       N
# 7   9    2400      D  D-penicillamine  15526   F       N            N       Y
# 8  10      51      D          Placebo  25772   F       Y            N       Y
# 9  11    3762      D          Placebo  19619   F       N            Y       Y
#
#   edema  bilirubin  cholesterol  albumin  copper  alk_phos    sgot  \
# 0     Y         14        261.0     2.60   156.0    1718.0  137.95
# 1     N          1        302.0     4.14    54.0    7394.8  113.52
# 2     S          1        176.0     3.48   210.0     516.0   96.10
# 3     S          1        244.0     2.54    64.0    6121.8   60.63
# 4     N          3        279.0     3.53   143.0     671.0  113.15
# 5     N          1        322.0     4.09    52.0     824.0   60.45
# 6     N          0        280.0     4.00    52.0    4651.2   28.38
# 7     N          3        562.0     3.08    79.0    2276.0  144.15
# 8     Y         12        200.0     2.74   140.0     918.0  147.25
# 9     N          1        259.0     4.16    46.0    1104.0   79.05
#
#    tryglicerides  platelets  prothrombin  stage
# 0          172.0      190.0           12      4
# 1           88.0      221.0           10      3
# 2           55.0      151.0           12      4
# 3           92.0      183.0           10      4
# 4           72.0      136.0           10      3
# 5          213.0      204.0            9      3
# 6          189.0      373.0           11      3
# 7           88.0      251.0           11      2
# 8          143.0      302.0           11      4
# 9           79.0      258.0           12      4

# %%
colors = ['orange','red', 'green', 'blue', 'yellow']
color_series = cirr['stage'].map(lambda s: colors[s])
plt.scatter(cirr['bilirubin'], cirr['prothrombin'], color=color_series)

# %%
sns.pairplot(cirr, hue='stage')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
features = ['bilirubin', 'prothrombin', 'albumin', 'copper', 'age', 'platelets', 'cholesterol']

X = cirr[features]
y = cirr[['stage']]

# %%
# Train/Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
# It's learning the means and stds of each of your features
ss.fit(X_train) # ONLY fit to X_train, NEVER to X_test

X_train_sc = ss.transform(X_train)
# It's find to TRANSFORM X_Test, just not .fit()
X_test_sc = ss.transform(X_test)

# %%
knn = KNeighborsClassifier()

# %%
# Default score for sklearn classification
# is accuracy: # of correct predictions / total predictions
cross_val_score(knn, X_train_sc, y_train, cv=5).mean()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:516: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# 0.5255813953488373

# %%
knn.fit(X_train_sc, y_train)
knn.score(X_train_sc, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# 0.6666666666666666

# %%
knn.score(X_test_sc, y_test)
# Out:
# 0.4057971014492754
